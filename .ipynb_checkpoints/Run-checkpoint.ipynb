# %%
# %load_ext autoreload
# %autoreload 2

# %%
import main
main.run(resume=False, eval_only=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-0b43431de876> in <module>()
#       1 import main
# ----> 2 main.run(resume=False, only_eval=True)
#
# TypeError: run() got an unexpected keyword argument 'only_eval'

# %%
import main
main.run()
# Out:
# MODEL ID:  ssdnet
# Created SSDNet model succesfully!
# Number of epochs: 32
# Total number of parameters of model:  3139688
# Total number of parameters given to optimizer:
# 3139688
# Model loaded successfully
# loading annotations into memory...
# Done (t=7.15s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.27s)
# creating index...
# index created!
# Train size:  16 50512 256
# Val size:  16 50512 256
# Only eval
# Average loss this epoch: Localization: 0.0; Classification: 0.0
# Validation start...
# Average precision:  0.09375
# Average Loc Loss:  0.0748861834854914
# Average Class Loss:  1.094673991203308  until batch:  1
# Average precision:  0.0625
# Average Loc Loss:  0.07562829136481519
# Average Class Loss:  1.1496936877568562  until batch:  2
# Average precision:  0.0546875
# Average Loc Loss:  0.0754093569967373
# Average Class Loss:  1.308293879032135  until batch:  3
# Average precision:  0.09375
# ...

# %%
import predict_and_plot
predict_and_plot.model_output_pipeline('misc/experiments/ssdnet/params.json')
# Out:
# Created SSDNet model succesfully!
# Model loaded successfully
# loading annotations into memory...
# Done (t=0.32s)
# creating index...
# index created!
# GT BBOXES:  [[ 33 140 294 249]] (1, 4)
# ALL ANCHORS WITH THEIR RESPECTIVE OFFSET PREDICTIONS:
# [[  0   0  32  32]
#  [  0   4  32  27]
#  [  6   0  25  32]
#  ...
#  [-80 -20 400 340]
#  [ 52 -80 268 400]
#  [ 16 -80 304 400]] (1980, 4)
# [[ -3   4  32  31]
#  [  0   8  30  24]
#  [  7   4  26  24]
#  ...
#  [  4   4 315 318]
#  [ 13  16 312 319]
#  [  4  19 315 320]] (1980, 4)
# Now let's see correct anchors and their respective predictions
# Matched ANCHORS:  [[ 80  80 240 240]
#  [ 31  31 288 288]
#  [ 31  83 288 236]
#  [ 31  63 288 256]
#  [  0  63 320 256]] (5, 4)
# Matched GT BBOXES:  [[ 33 140 294 249]
#  [ 33 140 294 249]
#  [ 33 140 294 249]
#  [ 33 140 294 249]
#  [ 33 140 294 249]] (5, 4)
# Matched Pred BBOXES:  [[ 38 128 270 238]
#  [ 32  50 314 259]
#  [ 30  83 303 225]
#  [ 33  70 307 244]
# ...
